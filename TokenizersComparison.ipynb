# %% [markdown]
# <a href="https://colab.research.google.com/github/Ali-Sharafeddine/FCS_Assignments/blob/main/TokenizersComparison.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
  # !pip3 install transformers -q

# %%
colors_list = [
'102;194;165', '252;141;98', '141;160;203',
'231;138;195', '166;216;84', '255;217;47'
]
from transformers import AutoTokenizer

def show_tokens(sentence, tokenizer_name):
    tokenizer = AutoTokenizer.from_pretrained(tokenizer_name)
    token_ids = tokenizer(sentence).input_ids
    print(f'length of token ids: {len(token_ids)}')
    for idx, t in enumerate(token_ids):
      print(
      f'\x1b[0;30;48;2;{colors_list[idx % len(colors_list)]}m' +
      tokenizer.decode(t) +
      '\x1b[0m',
      end=
      ' '
      )

# %%
show_tokens("Hello world!" , "google-bert/bert-base-cased")
# Out:
# length of token ids: 5
# [CLS] Hello world ! [SEP]

# %%
text ="""
English and CAPITALIZATION
🎵⻦
show_tokens False None elif == >= else: two tabs:" " Three tabs: " "
12.0*50=600
"""

# %%
show_tokens(text, "google-bert/bert-base-uncased")
# Out:
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# length of token ids: 40
# [CLS] english and capital ##ization [UNK] show _ token ##s false none eli ##f = = > = else : two tab ##s : " " three tab ##s : " " 12 . 0 * 50 = 600 [SEP]

# %%
show_tokens(text,"google-bert/bert-base-cased")
# Out:
# length of token ids: 48
# [CLS] English and CA ##PI ##TA ##L ##I ##Z ##AT ##ION [UNK] show _ token ##s F ##als ##e None el ##if = = > = else : two ta ##bs : " " Three ta ##bs : " " 12 . 0 * 50 = 600 [SEP]

# %%
show_tokens(text, "openai-community/gpt2")
# Out:
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# length of token ids: 46
#
#  English  and  CAP ITAL IZ ATION
#  � � � � � �
#  show _ t ok ens  False  None  el if  ==  >=  else :  two  tabs :"  "  Three  tabs :  "  "
#  12 . 0 * 50 = 600

# %%
show_tokens(text, "google/flan-t5-xxl")
# Out:
# tokenizer_config.json:   0%|          | 0.00/2.54k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.42M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.20k [00:00<?, ?B/s]
# length of token ids: 48
# English and CA PI TAL IZ ATION  <unk> show _ to ken s Fal s e None  e l if = = > = else : two tab s : " " Three tab s : " " 12. 0 * 50 = 600  </s>
